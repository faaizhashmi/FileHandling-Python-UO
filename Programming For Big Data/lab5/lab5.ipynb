# %%
students=[['Hisham', 'Butt', 'l1s16bscs0088', 60, 70, 50, 45, 55], ['Faaiz', 'chupi', 'l1s16bscs0114', 70, 40, 80, 35, 55]]

def fun1(lst,index ,course):
    lst=[]
    num=0
    for i in range(len(students)):
        lst.append(students[i][index])
    print('Max for course ', course, ' :',end=' ')
    print(max(lst))
    print('Min for course ', course, ' :',end=' ')
    print(min(lst))
    print('Avg for course ', course, ' :',end=' ')
    for j in range(len(lst)):
        num =num+lst[0]
    print(num/5)
    
def fun2(lst,index ,course):
    lst=[]
    num=0
    for i in range(len(students)):
        lst.append(students[i][index])
    lst.sort(reverse = True)
    print('highest for course ', course, ' :',end=' ')
    print(lst)
    
def fun3(lst):
    lst=[]
    for i in range(len(students)):
        k=3
        check=0
        print('Studend ',i,end="\n")
        for j in range(5):
            if students[i][k]<50:
                check=1
                print("Fail in course : ",j+1,end='\n')
            k=k+1
        if check==0:
            print("pass in every exam",end='\n')

fun1(students,3,1)
fun1(students,4,2)
fun1(students,5,3)
fun1(students,6,4)
fun1(students,7,5)

fun2(students,3,1)
fun2(students,4,2)
fun2(students,5,3)
fun2(students,6,4)
fun2(students,7,5)

fun3(students)
# Out:
# Max for course  1  : 70
# Min for course  1  : 60
# Avg for course  1  : 24.0
# Max for course  2  : 70
# Min for course  2  : 40
# Avg for course  2  : 28.0
# Max for course  3  : 80
# Min for course  3  : 50
# Avg for course  3  : 20.0
# Max for course  4  : 45
# Min for course  4  : 35
# Avg for course  4  : 18.0
# Max for course  5  : 55
# Min for course  5  : 55
# Avg for course  5  : 22.0
# highest for course  1  : [70, 60]
# highest for course  2  : [70, 40]
# highest for course  3  : [80, 50]
# highest for course  4  : [45, 35]
# highest for course  5  : [55, 55]
# Studend  0
# Fail in course :  4
# Studend  1
# Fail in course :  2
# Fail in course :  4

# %%
m1=[[1,2,3],[4,5,6]]
m2=[[4,5,6],[1,2,3]]
m3=[[1,2,3],[4,5,6]]
m4=[[4,5],[6,7],[8,9]]
r1=[]
r2=[]
r3=[]
lst=[]

for i in range(len(m1)):
    for j in range(len(m1[0])):
        lst.append(0)
    r1.append(lst)
    r2.append(lst)
    lst=[]
    
for i in range(len(m1[0])):
    for j in range(len(m2)):
        lst.append(0)
    r3.append(lst)
    lst=[]

for i in range(len(m1)):
    for j in range(len(m1[0])):
        n=m1[i][j]+m2[i][j]
        r1[i][j]=n
print(r1)

for i in range(len(m1)):
    for j in range(len(m1[0])):
        n=m1[i][j]-m2[i][j]
        r2[i][j]=n
print(r2)

for i in range(len(m3)):
    for j in range(len(m4[0])):
        for k in range(len(m4)):
            n=m3[i][k]*m4[k][j]
            r3[i][j]=n

print(r3)
# Out:
# [[5, 7, 9], [5, 7, 9]]
# [[-3, -3, -3], [3, 3, 3]]
# [[24, 27], [48, 54], [0, 0]]
